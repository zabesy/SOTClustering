# %%
from functions import *

# %% [markdown]
# SOT = School of Thought
#
# Load all texts. Remove the unnecessary parts in the start and end (different for each text). Append all texts to a list and dict.

# %%
#Plato
platos_works = read_and_load_text("phil_txts/plato/plato_complete_works.txt")
platos_works = platos_works.split("among the questions this dialogue leaves us to ponder.")[1][24:].split("18. Demeter, whose cult at Eleusis was")[0][:-1]
platos_combined_texts = [platos_works]

# %%
# Aristotle
aristotles_works_1 = read_and_load_text("phil_txts/aristotle/aristotle_complete_works_v1.txt")
aristotles_works_2 = read_and_load_text('phil_txts/aristotle/aristotle_complete_works_v2.txt')
aristotles_works_1 = aristotles_works_1.split("1a16-1a19")[1][24:].split("theory of colours.")[0]
aristotles_works_2 = aristotles_works_2.split("Translated by L. D. Dowdall2")[1][18:].split("epic, it will be the higher form of art.")[0]
aristotles_combined_texts = [aristotles_works_1, aristotles_works_2]

# %%
# Rationalists
spinoza_on_ethics = read_and_load_text("phil_txts/rationalists/spinoza_ethics.txt")
spinoza_understanding = read_and_load_text('phil_txts/rationalists/spinoza_improvment_of_understanding.txt')
leibnizs_on_theodicy = read_and_load_text('phil_txts/rationalists/leibniz_theodicy.txt')
descartes_discourse = read_and_load_text('phil_txts/rationalists/descartes_discourse_on_method.txt')
descartes_on_meditations = read_and_load_text("phil_txts/rationalists/descartes_meditations.txt")
malebranches_truth = read_and_load_text("phil_txts/rationalists/malebranche_search_truth.txt")

spinoza_on_ethics = spinoza_on_ethics.split("PART I. CONCERNING GOD.")[1][20:].split("But all things excellent are as difficult as they are")[0]
spinoza_understanding = spinoza_understanding.split("[1]  (1)")[1].split("knowledge of the first cause, or God.")[0]
leibnizs_on_theodicy = leibnizs_on_theodicy.split("Essays in _Theodicy_.")[1][180:].split("wherein at last the source of things must be sought.")[0]
descartes_discourse = descartes_discourse.split("PREFATORY NOTE BY THE AUTHOR")[1][1:].split("preferments.")[0]
descartes_on_meditations = descartes_on_meditations.split("Letter of Dedication")[1][1:].split("the human mind and the body.*")[0]
malebranches_truth = malebranches_truth.split("Avoid Error in the Sciences")[1][22:].split("to speak as does Scripture.~> only what the")[0]

rationalist_combined_texts = [spinoza_on_ethics, spinoza_understanding,
                    leibnizs_on_theodicy, descartes_discourse,
                     descartes_on_meditations, malebranches_truth]

# %%
# Empiricists
locke_humane_1 = read_and_load_text('phil_txts/empiricists/locke_humane_understanding_1.txt')
locke_humane_2 = read_and_load_text('phil_txts/empiricists/locke_humane_understanding_2.txt')
locke_government = read_and_load_text('phil_txts/empiricists/locke_treatise_of_government.txt')
hume_human_nature = read_and_load_text('phil_txts/empiricists/hume_human_nature.txt')
hume_religion = read_and_load_text('phil_txts/empiricists/hume_natural_religion.txt')
berkeley_human_knowledge = read_and_load_text('phil_txts/empiricists/berkley_principles_human_knowledge.txt')
berkeley_dialogues = read_and_load_text('phil_txts/empiricists/berkley_dialogues_hylas_philonous.txt')

locke_humane_1 = locke_humane_1.split("Your Lordship’s most humble and most obedient servant,")[1][101:].split("next Book.")[0]
locke_humane_2 = locke_humane_2.split("OF WORDS OR LANGUAGE IN GENERAL.")[1][51:].split("End of the Project Gutenberg")[0][:-53]
locke_government = locke_government.split("PREFACE")[1][4:].split('place it in new hands, as they think good.')[0]
hume_human_nature = hume_human_nature.split("VOL. I OF THE UNDERSTANDING.")[1][32:].split("End of Project Gutenberg")[0][:-38]
hume_religion = hume_religion.split('AMPHILUS TO HERMIPPUS')[1][6:].split("End of the Project Gutenberg")[0][:-50]
berkeley_human_knowledge = berkeley_human_knowledge.split("an opinion before they rightly")[1][44:].split("End of the Project Gutenberg")[0][:-22]
berkeley_dialogues = berkeley_dialogues.split("George Berkeley (1685-1753)")[1][34:].split("End of the Project Gutenberg")[0][:-50]

empiricist_combined_texts = [locke_government, locke_humane_1, locke_humane_2,
                    hume_human_nature, hume_religion, berkeley_dialogues,
                    berkeley_human_knowledge]

# %%
# German idealism
kant_critique_reason = read_and_load_text("phil_txts/german_idealism/kant_critique_practical_reason.txt")
kant_critique_judgement = read_and_load_text("phil_txts/german_idealism/kant_critique_judgement.txt")
kant_reason = read_and_load_text("phil_txts/german_idealism/kant_pure_reason.txt")
fichte_system_of_ethics = read_and_load_text("phil_txts/german_idealism/fichte_system_of_ethics.txt")
hegel_science_of_logic = read_and_load_text("phil_txts/german_idealism/hegel_science_of_logic.txt")
hegel_phenomenology_of_spirit = read_and_load_text("phil_txts/german_idealism/hegel_phenomenology_of_spirit.txt")
hegel_elements_of_right = read_and_load_text("phil_txts/german_idealism/hegel_elements_of_right.txt")

kant_critique_reason = kant_critique_reason.split("pracfifdjen Sernunff")[1][367:].split("evident to it.")[0]
kant_critique_judgement = kant_critique_judgement.split("judgement into the system of the critique of pure")[1][235:].split("References to Kant’s Critique")[0][:-92]
kant_reason = kant_reason.split("he Great Instauration. Preface")[1][2:].split("I don't care for the labors of Arcesilas or Solon")[0]
fichte_system_of_ethics = fichte_system_of_ethics.split("1796/97); WLnm [K]")[1][155:].split("as the final end of all ethics, rests.")[0]
hegel_science_of_logic = hegel_science_of_logic.split("Chapter 3. The absolute idea")[1][170:].split("conceptually comprehending itself.")[0]
hegel_phenomenology_of_spirit = hegel_phenomenology_of_spirit.split("ANALYSIS OF THE TEXT by J. N. Findlay")[1][64:].split("of Schiller's Die Freundschaft, ad fin.")[0]
hegel_elements_of_right = hegel_elements_of_right.split(" But a philosophical outline is not expected to conform to")[1][9:].split("and in the ideal world.")[0]

german_idealist_combined_texts = [kant_critique_reason, kant_critique_judgement, kant_reason,
                         fichte_system_of_ethics, hegel_science_of_logic, hegel_phenomenology_of_spirit, hegel_elements_of_right]

# %%
# Analytic
russell_philosophy_problems = read_and_load_text('phil_txts/analytic/russell_problems_of_philosophy.txt')
russell_analylsis = read_and_load_text('phil_txts/analytic/russell_analysis_of_mind.txt')
moore_phil_studies = read_and_load_text('phil_txts/analytic/moore_philosophical_studies.txt')
wittgenstein_logico_phil = read_and_load_text("phil_txts/analytic/wittgenstein_tractatus.txt")
wittgenstein_phil_investigations = read_and_load_text("phil_txts/analytic/wittgenstien_philosophical_investigations.txt")
lewis_papers_1 = read_and_load_text("phil_txts/analytic/lewis_papers_1.txt")
lewis_papers_2 = read_and_load_text("phil_txts/analytic/lewis_papers_2.txt")
quine_quintessence = read_and_load_text("phil_txts/analytic/quine_quintessence.txt")
popper_logic_of_science = read_and_load_text("phil_txts/analytic/popper_logic_of_science.txt")
kripke_phil_troubles = read_and_load_text("phil_txts/analytic/kripke_philosophical_troubles.txt")
kripke_naming_necessity = read_and_load_text("phil_txts/analytic/kripke_naming_necessity.txt")

russell_philosophy_problems = russell_philosophy_problems.split("PREFACE")[1].split("which constitutes its highest good.")[0]
russell_analylsis = russell_analylsis.split("of the expectations of the original")[1][45:].split("nearer to what actually exists.")[0]
moore_phil_studies = moore_phil_studies.split("PREFACE")[1][6:].split("I have not done justice.")[0]
wittgenstein_logico_phil = wittgenstein_logico_phil.split("T RANSLATORS’ P REFACE")[1][4:].split("e translators’ aim ")[0][:-43]
wittgenstein_phil_investigations = wittgenstein_phil_investigations.split("Augustine, Confessions,")[1][11:].split("mathematics'.")[0]
lewis_papers_1 = lewis_papers_1.split("American Philosophical Quarterly 15 (1978): 37-46.")[1][21:].split("about strangers now face")[0]
lewis_papers_2 = lewis_papers_2.split("we must choose one evil or another.")[1][68:].split("and that is perfectly consistent with these facts.")[0]
quine_quintessence = quine_quintessence.split("D U C T I O N I S")[1][43:].split("s that the step is sound only i n the case")[0]
popper_logic_of_science = popper_logic_of_science.split("Lord Acton")[1][56:].split("he Appendices i–vii ")[0][:-74]
kripke_phil_troubles = kripke_phil_troubles.split("uiry 40 (2009):367–86.")[1][170:].split("typical.32")[0][:-3]
kripke_naming_necessity = kripke_naming_necessity.split("n by Billing & Sons")[1][146:].split("de open and extremely confming.")[0]

analytic_combined_texts = [russell_analylsis, russell_philosophy_problems,
                  moore_phil_studies, wittgenstein_phil_investigations, wittgenstein_logico_phil,
                  lewis_papers_1, lewis_papers_2, quine_quintessence, popper_logic_of_science,
                  kripke_naming_necessity, kripke_phil_troubles]

# %%
# Phenomenology
merleau_ponty_on_perception = read_and_load_text("phil_txts/phenomenology/merleau-ponty_phenomenology_of_perception.txt")
husserl_phenomenology = read_and_load_text("phil_txts/phenomenology/husserl_idea_of_phenomenology.txt")
husserl_euro_science = read_and_load_text("phil_txts/phenomenology/husserl_crisis_of_euro_sciences.txt")
heidegger_time = read_and_load_text("phil_txts/phenomenology/heidegger_being_and_time.txt")
heidegger_beaten_track = read_and_load_text("phil_txts/phenomenology/heidegger_off_the_beaten_track.txt")

merleau_ponty_on_perception = merleau_ponty_on_perception.split("PART III Being-for-Itself and Being-in-the-World")[1][112:].split("rre, pp. 171, 174, 176.")[0][:-68]
husserl_phenomenology = husserl_phenomenology.split("I, The Hague: Martinus Nijhoff, 1973.")[1][23:].split("re of immediate evidence.")[0]
husserl_euro_science = husserl_euro_science.split("P A R T I")[1][106:].split("for ourselves).")[0]
heidegger_time = heidegger_time.split("the Seventh German Edition")[1][46:].split("itself reveal itself")[0]
heidegger_beaten_track = heidegger_beaten_track.split("gin ofthe Work ofArta")[1][4:].split("oximity to that which is to be thought.")[0]

phenomenology_combined_texts = [merleau_ponty_on_perception, husserl_euro_science,
                       husserl_phenomenology, heidegger_time, heidegger_beaten_track]

# %%
# Continental
foucault_order_of_things = read_and_load_text("phil_txts/continental/foucault_order_of_things.txt")
foucault_history_of_madness = read_and_load_text("phil_txts/continental/foucault_history_of_madness.txt")
foucault_birth_of_clinic = read_and_load_text("phil_txts/continental/foucault_birth_of_clinic.txt")
derrida_writing_and_difference = read_and_load_text("phil_txts/continental/derrida_writing_difference.txt")
deleuze_anti_oedipus = read_and_load_text("phil_txts/continental/deleuze_guattari_anti-oedipus.txt")
deleuze_diff_and_repetition = read_and_load_text("phil_txts/continental/deleuze_difference_repetition.txt")

foucault_order_of_things = foucault_order_of_things.split("but inaccurate, label.")[1][23:]
foucault_history_of_madness = foucault_history_of_madness.split("wrote the book to lay down the law")[1][146:].split("But where is the true naivety?")[0]
foucault_birth_of_clinic = foucault_birth_of_clinic.split("1. SPACES AND CLASSES")[2].split("but firm web of our experience.")[0]
derrida_writing_and_difference = derrida_writing_and_difference.split("hings and not enough forms.")[1][39:].split("reflexibility of our hands.")[0]
deleuze_anti_oedipus = deleuze_anti_oedipus.split("revolutionary movements.")[1][73:].split("ous tasks of schizoanalysis proceed.")[0]
deleuze_diff_and_repetition = deleuze_diff_and_repetition.split("REPETITION AND DIFFERENCE 1")[1].split(" cusp, causes them to return.")[0]

continental_combined_texts = [foucault_birth_of_clinic, foucault_history_of_madness, foucault_order_of_things,
                     derrida_writing_and_difference, deleuze_diff_and_repetition, deleuze_anti_oedipus]

# %%
# Marxism
marx_das_capital = read_and_load_text("phil_txts/marxism/marx_kapital.txt")
marx_communist_manifesto = read_and_load_text("phil_txts/marxism/marx_manifesto.txt")
lenin_essential_works = read_and_load_text("phil_txts/marxism/lenin_essential_works.txt")

marx_das_capital = marx_das_capital.split("ction 4 - The Fetishism")[1][288:].split("here of real Colonies, vi")[0][:-189]
marx_communist_manifesto = marx_communist_manifesto.split("London, February 1, 1893")[1][15:].split("Notes on")[0][:-82]
lenin_essential_works = str(lenin_essential_works.split("CONCLUSIONS TO CHAPTER I")[2:]).split("was to rule the world.")[0]

marxism_combined_texts = [marx_das_capital, marx_communist_manifesto, lenin_essential_works]

# %%
# Capitalist economics
smith_wealth_of_nations = read_and_load_text("phil_txts/capitalist_economics/smith_wealth_of_nations.txt")
ricardo_principles_economy = read_and_load_text("phil_txts/capitalist_economics/ricardo_principles_of_political_economy.txt")
keynes_theory_of_employment = read_and_load_text("phil_txts/capitalist_economics/keynes_theory_of_employment.txt")

smith_wealth_of_nations = smith_wealth_of_nations.split("CHAPTER III. OF PUBLIC DEBTS.")[1][60:].split("*** EN")[0]
ricardo_principles_economy = ricardo_principles_economy.split("XXIX. _Mr. Malthus's Opinions on Rent_")[1][69:].split("tly estimated by different persons.")[0]
keynes_theory_of_employment = keynes_theory_of_employment.split("**********")[1][108:].split("which are dangerous for good or evil.")[0]

capitalist_combined_texts = [smith_wealth_of_nations, ricardo_principles_economy, keynes_theory_of_employment]

# %% [markdown]
# Join all books to a dictionary.

# %%
sot_text_dict_list = {"rationalism": rationalist_combined_texts,
                      "analytic": analytic_combined_texts,
                      "empiricism": empiricist_combined_texts,
                      "phenomenology": phenomenology_combined_texts,
                      "capitalism":capitalist_combined_texts,
                      "continental":continental_combined_texts,
                      "plato":platos_combined_texts,
                      "aristotle": aristotles_combined_texts,
                      "german_idealism":german_idealist_combined_texts,
                      "marxism":marxism_combined_texts}

#Append a dot at the end of each text.
all_texts_in_string = ""
for index in sot_text_dict_list.keys():
    sot_text_dict_list[index] = [text + "." for text in sot_text_dict_list[index]]
    all_texts_in_string += " ".join(sot_text_dict_list[index])

# %% [markdown]
# Data cleaning.

# %%
#Number of words before cleaning
print(f"Num of words before cleaning: {len(all_texts_in_string.split(' '))}")
print(f"Num of sentences before cleaning: {len(all_texts_in_string.split('.'))}")

sot_text_dict_list_cleaned = text_cleaning(sot_text_dict_list)
# Out:
# Num of words before cleaning: 8423545
# Num of sentences before cleaning: 364464

# %% [markdown]
# Generate dataframe containing ['school','author', 'title', 'tokenized_sentence', 'num_of_chars', 'num_of_words', 'string_sentence'].

# %%
dataframe_sot = generate_dataframe(sot_text_dict_list_cleaned)

# %%
dataframe_sot["num_of_chars"] = dataframe_sot["tokenized_sentence"].map(lambda x: len(" ".join(x)))
dataframe_sot["num_of_words"] = dataframe_sot["tokenized_sentence"].map(lambda x: len(x))
dataframe_sot["string_sentence"] = dataframe_sot["tokenized_sentence"].map(lambda x: " ".join(x))
dataframe_sot.sample(5)
# Out:
#                school               author  \
# 115012  phenomenology       Edmund Husserl
# 45202        analytic  David Kellogg Lewis
# 304114      aristotle            Aristotle
# 135864  phenomenology     Martin Heidegger
# 265063      aristotle            Aristotle
#
#                                                     title  \
# 115012  the crisis of european sciences and transcende...
# 45202                       philosophical papers volume 1
# 304114              the complete works of aristotle vol 2
# 135864                               off the beaten track
# 265063              the complete works of aristotle vol 1
#
#                                        tokenized_sentence  num_of_chars  \
# 115012   [within, self, evidence, great, deal, comprised]            41
# 45202                                          [credible]             8
# 304114                        [form, qualified, metaphor]            23
# ...

# %% [markdown]
# Remove rows that contains few characters.
# Remove rows that contains less than 2 & 3 chars.
# Remove sentences that contains more than 150 words, most cases it's sentences from the preface or appendix that's convoluting the flow.

# %%
dataframe_sot[dataframe_sot["num_of_words"] < 150].sample(5)
# Out:
#              school               author  \
# 284148    aristotle            Aristotle
# 68828      analytic          Saul Kripke
# 67766      analytic          Karl Popper
# 276671    aristotle            Aristotle
# 20318   rationalism  Nicolas Malebranche
#
#                                         title  \
# 284148  the complete works of aristotle vol 2
# 68828                    naming and necessity
# 67766       the logic of scientific discovery
# 276671  the complete works of aristotle vol 2
# 20318     malebranche: the search after truth
#
#                                        tokenized_sentence  num_of_chars  \
# 284148  [claim, intimate, textual, studies, recent, sc...            56
# 68828   [apology, text, stands, aware, list, footnote,...            57
# 67766   [sprang, see, misunderstanding, meaning, forma...            76
# 276671                                                 []             0
# ...

# %%
dataframe_sot = dataframe_sot.drop(dataframe_sot[dataframe_sot["num_of_words"] > 150].index)
dataframe_sot.reset_index(drop = True, inplace = True)

# %%
dataframe_sot[dataframe_sot["num_of_chars"] < 2].sample(5)
# Out:
#                  school                         author  \
# 114097    phenomenology                 Edmund Husserl
# 199952            plato                          Plato
# 350076  german_idealism  Georg Wilhelm Friedrich Hegel
# 371002          marxism                      Karl Marx
# 269401        aristotle                      Aristotle
#
#                                                     title tokenized_sentence  \
# 114097  the crisis of european sciences and transcende...                 []
# 199952                              plato: complete works                 []
# 350076                elements of the philosophy of right                 []
# 371002                                        das kapital                 []
# 269401              the complete works of aristotle vol 1                 []
#
#         num_of_chars  num_of_words string_sentence
# 114097             0             0
# 199952             0             0
# 350076             0             0
# ...

# %%
dataframe_sot = dataframe_sot.drop(dataframe_sot[dataframe_sot["num_of_chars"] < 2].index)
dataframe_sot.reset_index(drop = True, inplace = True)

# %%
dataframe_sot[dataframe_sot["num_of_chars"] < 3].sample(5)
# Out:
#                  school            author                    title  \
# 155757      continental   Michel Foucault      the order of things
# 24453          analytic  Bertrand Russell     the analysis of mind
# 211328            plato             Plato    plato: complete works
# 213514            plato             Plato    plato: complete works
# 281025  german_idealism     Immanuel Kant  critique of pure reason
#
#        tokenized_sentence  num_of_chars  num_of_words string_sentence
# 155757               [pp]             2             1              pp
# 24453                [dr]             2             1              dr
# 211328               [ff]             2             1              ff
# 213514               [ff]             2             1              ff
# 281025               [bk]             2             1              bk

# %%
dataframe_sot = dataframe_sot.drop(dataframe_sot[dataframe_sot["num_of_chars"] < 3].index)
dataframe_sot.reset_index(drop = True, inplace = True)

# %% [markdown]
# Remove duplicates that has more than 2 words.

# %%
print(len(dataframe_sot['string_sentence'])-len(dataframe_sot['string_sentence'].unique()))

duplicates_in_dataframe = pd.concat(group for _, group in dataframe_sot.groupby("string_sentence") if len(group) > 1)
duplicates_in_dataframe.sample(5)
# Out:
# 21745
#                  school         author                                  title  \
# 280676  german_idealism  Immanuel Kant                critique of pure reason
# 193645            plato          Plato                  plato: complete works
# 203049            plato          Plato                  plato: complete works
# 179367            plato          Plato                  plato: complete works
# 255104        aristotle      Aristotle  the complete works of aristotle vol 2
#
#                                        tokenized_sentence  num_of_chars  \
# 280676                                              [div]             3
# 193645                                       [chaerephon]            10
# 203049                                       [absolutely]            10
# 179367                                          [clearly]             7
# 255104  [box, charlottesville, virginia, available, vi...            66
#
# ...

# %%
indexes_to_remove = dataframe_sot[(dataframe_sot["string_sentence"].duplicated(keep=False)) & (dataframe_sot["num_of_words"] > 2)].index
print(len(dataframe_sot))
dataframe_sot.drop(dataframe_sot.index[indexes_to_remove], inplace=True)
dataframe_sot.reset_index(drop = True, inplace = True)

print(len(dataframe_sot))
# Out:
# 334212
# 327431

# %%
#Number of rows in dataframe.
print(len(dataframe_sot))
#Print how many sentences each SOT has.
dataframe_sot["school"].value_counts(normalize=True)
# Out:
# 327431
# analytic           0.152151
# aristotle          0.150658
# german_idealism    0.130956
# plato              0.127205
# continental        0.101230
# phenomenology      0.087057
# rationalism        0.071459
# marxism            0.064591
# empiricism         0.058501
# capitalism         0.056192
# Name: school, dtype: float64

# %%
dataframe_sot["school"].value_counts()
# Out:
# analytic           49819
# aristotle          49330
# german_idealism    42879
# plato              41651
# continental        33146
# phenomenology      28505
# rationalism        23398
# marxism            21149
# empiricism         19155
# capitalism         18399
# Name: school, dtype: int64

# %% [markdown]
# Number of words after data cleaning

# %%
print(f"Number of sentences after cleaning: {len(dataframe_sot['num_of_words'])}")
print(f"Number of words after cleaning: {dataframe_sot['num_of_words'].sum()}")
print(f"Average words per sentence: {dataframe_sot['num_of_words'].sum()/len(dataframe_sot['num_of_words'])}")
print(f"Standard deviation of words per sentence: {stdev(dataframe_sot['num_of_words'])}")

plt.figure(figsize=(8,5))
dataframe_sot.num_of_words.plot(kind='hist', bins=200)
plt.title('Number of words per sentence')
plt.ylabel("Sentence count")
plt.xlabel("Word count")
plt.grid()
plt.show()

plt.figure(figsize=(8,5))
sns.violinplot(x='school', y='num_of_words', data=dataframe_sot)
plt.title('Sentence Length - By School')
plt.xticks(rotation=20)
plt.grid()
# Out:
# Number of sentences after cleaning: 327431
# Number of words after cleaning: 3515377
# Average words per sentence: 10.736237558447428
# Standard deviation of words per sentence: 7.952388714933085

# %% [markdown]
# Generate a word frequency bar plot after cleaning the data.

# %%
total_word_count_dict = {}
school_word_count_dict = {}
for index, row in dataframe_sot.iterrows():
    if school_word_count_dict.get(row["school"]) is None:
        school_word_count_dict[row["school"]] = {}
    for word in row["tokenized_sentence"]:
        if word not in total_word_count_dict:
            total_word_count_dict[word] = 1
        else:
            total_word_count_dict[word] += 1
        if word not in school_word_count_dict[row["school"]]:
            school_word_count_dict[row["school"]][word] = 1
        else:
            school_word_count_dict[row["school"]][word] += 1

# %%
#Sort the dictionaries into list of tuples
sorted_total_word_count = sorted(total_word_count_dict.items(), key=lambda x: x[1], reverse=True)

sorted_school_word_count = dict.fromkeys(dataframe_sot["school"].unique(), None)
for school, temp_dict in school_word_count_dict.items():
    sorted_school_word_count[school] = sorted(temp_dict.items(), key=lambda x: x[1], reverse=True)

# %%
#Plot total word count.
count = 15
plt.bar(range(len(sorted_total_word_count[:count])), [value[1] for value in sorted_total_word_count[:count]], align='center')
plt.xticks(range(len(sorted_total_word_count[:count])), [val[0] for val in sorted_total_word_count[:count]])
plt.xticks(rotation=70)
plt.xlabel("Word")
plt.ylabel("Count")
plt.title(f"Total word frequency")
plt.show()

# %%
#Plot word count per SOT.
for school, list_tuples in sorted_school_word_count.items():
    plt.figure(figsize=(8,6))
    plt.tight_layout()
    plt.bar(range(len(list_tuples[:count])), [value[1] for value in list_tuples[:count]], align='center')
    plt.xticks(range(len(list_tuples[:count])), [val[0] for val in list_tuples[:count]])
    plt.xticks(rotation=70)
    plt.xlabel("Word")
    plt.ylabel("Count")
    plt.title(f"{school.capitalize()}")
    plt.show()

# %%
start = time.time()
for school in dataframe_sot["school"].unique():

    # print(dataframe_sot[dataframe_sot["school"]==school].tokenized_sentence.sample(5))
    text = " ".join(" ".join(txt) for txt in dataframe_sot[dataframe_sot["school"]==school].tokenized_sentence)
    word_cloud = WordCloud(stopwords=set(stopwords.words("english")), max_font_size=50, max_words=300,
                                     width = 450, height = 300,
                                     background_color="white").generate(text)
    plt.figure(figsize=(8,6))
    plt.imshow(word_cloud, interpolation="bilinear")
    plt.title(school.capitalize())
    plt.axis("off")
    plt.show()
end = time.time()
print('Elapsed time: ', end-start)
# Out:
# Elapsed time:  43.9114511013031

# %% [markdown]
# Save dataframe to csv.

# %%
dataframe_sot.to_csv("philosophy_data.csv", index=False)
